# %%
# Download graphviz https://graphviz.gitlab.io/_pages/Download/Download_windows.html from https://stackoverflow.com/questions/35064304/runtimeerror-make-sure-the-graphviz-executables-are-on-your-systems-path-aft

import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'

# %%
from graphviz import Digraph
import networkx as nx

# %%
# Inputs:
sizeX = 3
sizeY = sizeX   # next character prediction
alphabet = ['c', 'a', 't', 'e', ' ']
sizeAlphabet = len(alphabet)

# %%
###############################################################################
#             Create Graph Structure (using only metadata of the network)
###############################################################################

# f is the graph constructed from RNN Inputs
G = nx.balanced_tree(r=sizeAlphabet, h=sizeX)
f = Digraph('balanced_tree', filename='balanced_3_5.gv')
f.attr(rankdir='LR', size='8,5')

# f.attr('node', shape='doublecircle')
for b_node in G.nodes:
    f.node("S"+str(b_node), H="", Y="")

# f.attr('node', shape='circle')

for i, b_edge in enumerate(G.edges):
    label = alphabet[i%sizeAlphabet]
    f.edge("S"+str(b_edge[0]), "S"+str(b_edge[1]), label)

# %%
f.view()
# Out:
# 'balanced_3_5.gv.pdf'

# %%
###############################################################################
#             Setup State Values (using trained information of the network)
###############################################################################
# I need to feed a trained model with all possible inputs to get responses y and h


# TODO: get the model that returns H and Y at every step

for b_node in f:
    print(b_node)
# Out:
# digraph balanced_tree {
# 	rankdir=LR size="8,5"
# 	S0 [H="" Y=""]
# 	S1 [H="" Y=""]
# 	S2 [H="" Y=""]
# 	S3 [H="" Y=""]
# 	S4 [H="" Y=""]
# 	S5 [H="" Y=""]
# 	S6 [H="" Y=""]
# 	S7 [H="" Y=""]
# 	S8 [H="" Y=""]
# 	S9 [H="" Y=""]
# 	S10 [H="" Y=""]
# 	S11 [H="" Y=""]
# 	S12 [H="" Y=""]
# 	S13 [H="" Y=""]
# 	S14 [H="" Y=""]
# 	S15 [H="" Y=""]
# 	S16 [H="" Y=""]
# 	S17 [H="" Y=""]
# 	S18 [H="" Y=""]
# 	S19 [H="" Y=""]
# 	S20 [H="" Y=""]
# 	S21 [H="" Y=""]
# 	S22 [H="" Y=""]
# 	S23 [H="" Y=""]
# 	S24 [H="" Y=""]
# 	S25 [H="" Y=""]
# 	S26 [H="" Y=""]
# 	S27 [H="" Y=""]
# 	S28 [H="" Y=""]
# 	S29 [H="" Y=""]
# 	S30 [H="" Y=""]
# 	S31 [H="" Y=""]
# 	S32 [H="" Y=""]
# 	S33 [H="" Y=""]
# 	S34 [H="" Y=""]
# 	S35 [H="" Y=""]
# 	S36 [H="" Y=""]
# 	S37 [H="" Y=""]
# 	S38 [H="" Y=""]
# 	S39 [H="" Y=""]
# 	S40 [H="" Y=""]
# 	S41 [H="" Y=""]
# 	S42 [H="" Y=""]
# 	S43 [H="" Y=""]
# 	S44 [H="" Y=""]
# 	S45 [H="" Y=""]
# 	S46 [H="" Y=""]
# 	S47 [H="" Y=""]
# 	S48 [H="" Y=""]
# 	S49 [H="" Y=""]
# ...

# %%
nx.set_node_attributes(G, bb, 'betweenness')

# %% [raw]
# f = Digraph('finite_state_machine', filename='fsm.gv')
# f.attr(rankdir='LR', size='8,5')
#
# f.attr('node', shape='doublecircle')
# f.node('LR_0')
# f.node('LR_3')
# f.node('LR_4')
# f.node('LR_8')
#
# f.attr('node', shape='circle')
# f.edge('LR_0', 'LR_2', label='SS(B)')
# f.edge('LR_0', 'LR_1', label='SS(S)')
# f.edge('LR_1', 'LR_3', label='S($end)')
# f.edge('LR_2', 'LR_6', label='SS(b)')
# f.edge('LR_2', 'LR_5', label='SS(a)')
# f.edge('LR_2', 'LR_4', label='S(A)')
# f.edge('LR_5', 'LR_7', label='S(b)')
# f.edge('LR_5', 'LR_5', label='S(a)')
# f.edge('LR_6', 'LR_6', label='S(b)')
# f.edge('LR_6', 'LR_5', label='S(a)')
# f.edge('LR_7', 'LR_8', label='S(b)')
# f.edge('LR_7', 'LR_5', label='S(a)')
# f.edge('LR_8', 'LR_6', label='S(b)')
# f.edge('LR_8', 'LR_5', label='S(a)')
#
# f.view()
